# %% [markdown]
# <a href="https://colab.research.google.com/github/TanmayRavulapalli/CancerAI/blob/main/cancer_detection1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Importation**

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/TanmayRavulapalli/CancerAI/refs/heads/main/cancer.csv")
df
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0                      1        17.99         10.38          122.80
# 1                      1        20.57         17.77          132.90
# 2                      1        19.69         21.25          130.00
# 3                      1        11.42         20.38           77.58
# 4                      1        20.29         14.34          135.10
# ..                   ...          ...           ...             ...
# 564                    1        21.56         22.39          142.00
# 565                    1        20.13         28.25          131.20
# 566                    1        16.60         28.08          108.30
# 567                    1        20.60         29.33          140.10
# 568                    0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# # **Data preparation**

# %% [markdown]
# ## **split into x and y**

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/TanmayRavulapalli/CancerAI/refs/heads/main/cancer.csv")

y= df['fractal_dimension_worst']
y
# Out:
# 0      0.11890
# 1      0.08902
# 2      0.08758
# 3      0.17300
# 4      0.07678
#         ...
# 564    0.07115
# 565    0.06637
# 566    0.07820
# 567    0.12400
# 568    0.07039
# Name: fractal_dimension_worst, Length: 569, dtype: float64

# %%
x = df.drop('fractal_dimension_worst', axis = 1)
x
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 0                      1        17.99         10.38          122.80
# 1                      1        20.57         17.77          132.90
# 2                      1        19.69         21.25          130.00
# 3                      1        11.42         20.38           77.58
# 4                      1        20.29         14.34          135.10
# ..                   ...          ...           ...             ...
# 564                    1        21.56         22.39          142.00
# 565                    1        20.13         28.25          131.20
# 566                    1        16.60         28.08          108.30
# 567                    1        20.60         29.33          140.10
# 568                    0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# # **Data splitting**

# %% [markdown]
# ## **splitting into training and test data**

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2 , random_state = 100)

# %%
x_train
# Out:
#      diagnosis(1=m, 0=b)  radius_mean  texture_mean  perimeter_mean  \
# 58                     0       13.050         19.31           82.61
# 554                    0       12.880         28.92           82.50
# 351                    1       15.750         19.22          107.10
# 136                    0       11.710         16.67           74.72
# 497                    0       12.470         17.31           80.45
# ..                   ...          ...           ...             ...
# 526                    0       13.460         18.75           87.44
# 53                     1       18.220         18.70          120.30
# 350                    0       11.660         17.07           73.70
# 79                     0       12.860         18.00           83.19
# 520                    0        9.295         13.90           59.96
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 58       527.2          0.08060           0.03789        0.000692
# ...

# %% [markdown]
# # **Model building**

# %% [markdown]
# ## **linear regession**

# %% [markdown]
# ### training the model

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### prediction training

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)

# %%
(y_lr_train_pred)
# Out:
# array([0.06321657, 0.07229309, 0.10330823, 0.07100256, 0.08247726,
#        0.08686839, 0.09749796, 0.07342084, 0.07934953, 0.08719848,
#        0.06556641, 0.0707968 , 0.07614519, 0.084609  , 0.08929921,
#        0.12050814, 0.07510044, 0.08618337, 0.07647964, 0.08673844,
#        0.07444076, 0.08131013, 0.06091704, 0.07179571, 0.07541414,
#        0.07061122, 0.11645504, 0.09730352, 0.06622569, 0.08635521,
#        0.09129542, 0.09339864, 0.09568826, 0.07211199, 0.07883708,
#        0.07584311, 0.08249172, 0.10218505, 0.0737063 , 0.11974447,
#        0.07472328, 0.11819564, 0.14009381, 0.07539255, 0.07883174,
#        0.08886958, 0.07734213, 0.06812381, 0.08077469, 0.07888393,
#        0.07998266, 0.08677292, 0.07678814, 0.10793207, 0.06873516,
#        0.07708976, 0.08629489, 0.0778795 , 0.0704057 , 0.07731739,
#        0.07424323, 0.07370101, 0.06629028, 0.10428368, 0.06923805,
#        0.07038425, 0.08864224, 0.08502664, 0.06738541, 0.08036988,
# ...

# %%
(y_lr_test_pred)
# Out:
# array([0.11265438, 0.06224688, 0.06015536, 0.07558285, 0.08917648,
#        0.09159329, 0.062476  , 0.08028764, 0.07571769, 0.07914376,
#        0.09175961, 0.10005941, 0.07991427, 0.08393291, 0.06038201,
#        0.09730272, 0.07746333, 0.06987946, 0.08443474, 0.08155983,
#        0.05864154, 0.06743118, 0.09446741, 0.08738546, 0.13537594,
#        0.09964811, 0.08206142, 0.0867877 , 0.09795769, 0.06263451,
#        0.10141393, 0.07498064, 0.06150326, 0.1203067 , 0.10370825,
#        0.07322435, 0.07440706, 0.07498495, 0.07854236, 0.09789862,
#        0.1050562 , 0.06829062, 0.08335267, 0.13049457, 0.07059889,
#        0.12377129, 0.07070021, 0.06732831, 0.09519395, 0.13672489,
#        0.07441552, 0.07852732, 0.07100476, 0.06478554, 0.09043102,
#        0.11210572, 0.07484207, 0.1664116 , 0.16694005, 0.06776278,
#        0.09163389, 0.10368312, 0.0802647 , 0.09427345, 0.12760217,
#        0.07767478, 0.0648996 , 0.09344472, 0.08195859, 0.06580967,
# ...

# %% [markdown]
# ### **evaluate model performance**

# %% [markdown]
# we compare the predicted values with the original values

# %%
from sklearn.metrics import mean_squared_error, r2_score

lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
print("LR MSE(train): " , lr_train_mse)
print("LR R2(train): " , lr_train_r2)
print("LR MSE(test): " , lr_test_mse)
print("LR R2(test): " , lr_test_r2)
# Out:
# LR MSE(train):  1.647138499203054e-05
# LR R2(train):  0.9447193629745431
# LR MSE(test):  3.2397069933379944e-05
# LR R2(test):  0.9250895143158246

# %%
lr_results = pd.DataFrame(['Linear regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns=['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']

# %%
lr_results
# Out:
#               Method Training MSE Training R2  Test MSE  Test R2
# 0  Linear regression     0.000016    0.944719  0.000032  0.92509

# %% [markdown]
# ## **Random forest**

# %% [markdown]
# ### **training the model**

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_depth=2 , random_state=100)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=100)

# %% [markdown]
# ### **make prediction**

# %%
y_rf_train_pred = rf.predict(x_train)
y_rf_test_pred = rf.predict(x_test)

# %% [markdown]
# ### **evaluate model performance**

# %%
from sklearn.metrics import mean_squared_error, r2_score

rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_train_r2 = r2_score(y_train, y_rf_train_pred)

rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Linear regression', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns=['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
rf_results
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression     0.000076    0.746493  0.000131  0.697975

# %% [markdown]
# # **Model comparision**

# %%
df_model = pd.concat([lr_results , rf_results] , axis=0)
df_model
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression     0.000016    0.944719  0.000032   0.92509
# 0  Linear regression     0.000076    0.746493  0.000131  0.697975

# %%
df_model.reset_index(drop=True)
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression     0.000016    0.944719  0.000032   0.92509
# 1  Linear regression     0.000076    0.746493  0.000131  0.697975

# %% [markdown]
# # **Data visualization**

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.scatter(x=y_train, y=y_lr_train_pred , alpha = 0.3)

z = np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(z)

plt.plot(y_train , p(y_train) , color = 'red')
plt.ylabel('Predicted values')
plt.xlabel('Real values')
plt.title('Linear regression')
# Out:
# Text(0.5, 1.0, 'Linear regression')
